# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Hassan Ahmed Khan__

# %% [markdown]
# Business Analyst

# %% [markdown]
# _I am interested in Data Science because it is an emerging feild and has great potential in future._

# %% [markdown]
# ### Gives you a square of 2

# %%
2**2
# Out:
# 4

# %% [markdown]
# -  Apple
# -  Oranges

# %% [markdown]
# 1. One
# 2. Two

# %% [markdown]
# |Height|Age  |
# |------|-----|
# |5.4   |20   |
# |6.0   |23   |
